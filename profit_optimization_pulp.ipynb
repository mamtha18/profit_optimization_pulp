# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in c:\users\mamtha h\appdata\local\programs\python\python310\lib\site-packages (3.3.0)
# [notice] A new release of pip available: 22.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pulp import *

# %%
model = LpProblem("Profit_Maximization", LpMaximize)

# %%
x = LpVariable('Product_A', lowBound=0)
y = LpVariable('Product_B', lowBound=0)

# %%
model += 40 * x + 30 * y

# %%
model += 2*x + y <= 100
model += 3*x + 2*y <= 120

# %%
model.solve()
# Out:
# 1

# %%
print("Status:", LpStatus[model.status])
print("Product A units:", x.varValue)
print("Product B units:", y.varValue)
print("Maximum Profit: ₹", value(model.objective))
# Out:
# Status: Optimal
# Product A units: 0.0
# Product B units: 60.0
# Maximum Profit: ₹ 1800.0
